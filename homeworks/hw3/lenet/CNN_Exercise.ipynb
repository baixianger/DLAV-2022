# %% [markdown]
# <a href="https://colab.research.google.com/github/baixianger/DLAV-2022/blob/main/homeworks/hw3/CNN_Exercise.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ## Convolutional Networks
#
# We'll check out how to build a **convolutional network** to classify CIFAR10 images. By using weight sharing - multiple units with the same weights - convolutional layers are able to learn repeated patterns in your data. For example, a unit could learn the pattern for an eye, or a face, or lower level features like edges.

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
import numpy as np
import time

import torch
from torch import nn
from torch import optim
import torch.nn.functional as F
import torch.utils.data as utils
from torchvision import datasets, transforms
from torch.utils.data.sampler import SubsetRandomSampler
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
label_names = [
    'airplane',
    'automobile',
    'bird',
    'cat',
    'deer',
    'dog',
    'frog',
    'horse',
    'ship',
    'truck'
]


def plot_images(images, cls_true, cls_pred=None):
    """
    Adapted from https://github.com/Hvass-Labs/TensorFlow-Tutorials/
    """
    fig, axes = plt.subplots(3, 3)

    for i, ax in enumerate(axes.flat):
        # plot img
        ax.imshow(images[i, :, :, :], interpolation='spline16')

        # show true & predicted classes
        cls_true_name = label_names[cls_true[i]]
        if cls_pred is None:
            xlabel = "{0} ({1})".format(cls_true_name, cls_true[i])
        else:
            cls_pred_name = label_names[cls_pred[i]]
            xlabel = "True: {0}\nPred: {1}".format(
                cls_true_name, cls_pred_name
            )
        ax.set_xlabel(xlabel)
        ax.set_xticks([])
        ax.set_yticks([])

    plt.show()

# %%
def get_train_valid_loader(data_dir='data',
                           batch_size=64,
                           augment=False,
                           random_seed = 1,
                           valid_size=0.02,
                           shuffle=True,
                           show_sample=True,
                           num_workers=4,
                           pin_memory=False):
    """
    Utility function for loading and returning train and valid
    multi-process iterators over the CIFAR-10 dataset. A sample
    9x9 grid of the images can be optionally displayed.
    If using CUDA, num_workers should be set to 1 and pin_memory to True.
    Params
    ------
    - data_dir: path directory to the dataset.
    - batch_size: how many samples per batch to load.
    - augment: whether to apply the data augmentation scheme
      mentioned in the paper. Only applied on the train split.
    - random_seed: fix seed for reproducibility.
    - valid_size: percentage split of the training set used for
      the validation set. Should be a float in the range [0, 1].
    - shuffle: whether to shuffle the train/validation indices.
    - show_sample: plot 9x9 sample grid of the dataset.
    - num_workers: number of subprocesses to use when loading the dataset.
    - pin_memory: whether to copy tensors into CUDA pinned memory. Set it to
      True if using GPU.
    Returns
    -------
    - train_loader: training set iterator.
    - valid_loader: validation set iterator.
    """
    error_msg = "[!] valid_size should be in the range [0, 1]."
    assert ((valid_size >= 0) and (valid_size <= 1)), error_msg

    normalize = transforms.Normalize(
        mean=[0.4914, 0.4822, 0.4465],
        std=[0.2023, 0.1994, 0.2010],
    )

    # define transforms
    valid_transform = transforms.Compose([
            transforms.ToTensor(),
            normalize,
    ])
    if augment:
        train_transform = transforms.Compose([
            transforms.RandomCrop(32, padding=4),
            transforms.RandomHorizontalFlip(),
            transforms.ToTensor(),
            normalize,
        ])
    else:
        train_transform = transforms.Compose([
            transforms.ToTensor(),
            normalize,
        ])

    # load the dataset
    train_dataset = datasets.CIFAR10(
        root=data_dir, train=True,
        download=True, transform=train_transform,
    )

    valid_dataset = datasets.CIFAR10(
        root=data_dir, train=True,
        download=True, transform=valid_transform,
    )

    num_train = len(train_dataset)
    indices = list(range(num_train))
    split = int(np.floor(valid_size * num_train))

    if shuffle:
        np.random.seed(random_seed)
        np.random.shuffle(indices)

    train_idx, valid_idx = indices[split:], indices[:split]
    train_sampler = SubsetRandomSampler(train_idx)
    valid_sampler = SubsetRandomSampler(valid_idx)

    train_loader = torch.utils.data.DataLoader(
        train_dataset, batch_size=batch_size, sampler=train_sampler,
        num_workers=num_workers, pin_memory=pin_memory,
    )
    valid_loader = torch.utils.data.DataLoader(
        valid_dataset, batch_size=batch_size, sampler=valid_sampler,
        num_workers=num_workers, pin_memory=pin_memory,
    )

    # visualize some images
    if show_sample:
        sample_loader = torch.utils.data.DataLoader(
            train_dataset, batch_size=9, shuffle=shuffle,
            num_workers=num_workers, pin_memory=pin_memory,
        )
        data_iter = iter(sample_loader)
        images, labels = data_iter.next()
        X = images.numpy().transpose([0, 2, 3, 1])
        plot_images(X, labels)

    return (train_loader, valid_loader)

# check cuda
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")

if torch.cuda.is_available():
    print("Found CUDA device, setting copy tensors into CUDA pinned memory")
    trainloader, valloader = get_train_valid_loader(num_workers=1, pin_memory=True)
else:
    from multiprocessing import cpu_count
    print(f"Found {cpu_count()} CPU kernals, load data.....")
    trainloader, valloader = get_train_valid_loader(num_workers=cpu_count(), pin_memory=False)
# Out:
# Found CUDA device, setting copy tensors into CUDA pinned memory
# Files already downloaded and verified
# Files already downloaded and verified
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).

# %% [markdown]
# Fomular
# $$
# \text{out}(N_i, C_{\text{out}_j}) = \text{bias}(C_{\text{out}_j}) +
# \sum_{k = 0}^{C_{\text{in}} - 1} \text{weight}(C_{\text{out}_j}, k) \star \text{input}(N_i, k)
# $$
# where :
# - $\star$ is the valid 2D `cross-correlation`_ operator,
# - `N` is a batch size,
# - `C` denotes a number of channels,
# - `H` is a height of input planes in pixels,
# - `W` iswidth in pixels.
#
# Shape
# - Input: $(N, C_{in}, H_{in}, W_{in})$
# - Output:$(N, C_{out}, H_{out}, W_{out})$
#
# where:
#
# - $ H_{out} = \left\lfloor\frac{H_{in}  + 2 \times \text{padding}[0] - \text{dilation}[0]
#                         \times (\text{kernel\_size}[0] - 1) - 1}{\text{stride}[0]} + 1\right\rfloor
# $
# - $ W_{out} = \left\lfloor\frac{W_{in}  + 2 \times \text{padding}[1] - \text{dilation}[1]
#                         \times (\text{kernel\_size}[1] - 1) - 1}{\text{stride}[1]} + 1\right\rfloor
# $

# %%
class ConvNet(nn.Module):
    def __init__(self, n_input_channels=3, n_output=10):
        super().__init__()
        ################################################################################
        # TODO:                                                                        #
        # Define 2 or more different layers of the neural network                      #
        ################################################################################
        # use the LeNet model
        # '?' denotes the batch size, which is 64 in our default setting from func above
        self.conv1 = nn.Conv2d(3, 6, 5)       # (?, 3,32,32) => (?, 6,28,28)
        self.pool = nn.MaxPool2d(2, 2)        # we use this pooling twice
                                              # 1st time :(?, 6,28,28) => (?, 6,14,14)
                                              # 2nd time :(?,16,10,10) => (?,16, 5, 5)
        self.conv2 = nn.Conv2d(6, 16, 5)      # (?, 6,14,14) => (?,16,10,10)
        self.fc1 = nn.Linear(16 * 5 * 5, 120) # (?,16, 5, 5) ~ (?,400) => (?,120)
        self.fc2 = nn.Linear(120, 84)         # (?,120) => (?,84)
        self.fc3 = nn.Linear(84, 10)          # (?, 84) => (?,10)
        ################################################################################
        #                              END OF YOUR CODE                                #
        ################################################################################
    
    def forward(self, x):
        ################################################################################
        # TODO:                                                                        #
        # Set up the forward pass that the input data will go through.                 #
        # A good activation function betweent the layers is a ReLu function.           #
        #                                                                              #
        # Note that the output of the last convolution layer should be flattened       #
        # before being inputted to the fully connected layer. We can flatten           #
        # Tensor `x` with `x.view`.                                                    #
        ################################################################################
        x = self.pool(F.relu(self.conv1(x)))
        x = self.pool(F.relu(self.conv2(x)))
        x = torch.flatten(x, 1) # only keep the batch dim, flatten rest dims
        # alternatively 
        # x = x.view(x.size[0], -1)
        x = F.relu(self.fc1(x))
        x = F.relu(self.fc2(x))
        x = self.fc3(x)
        ################################################################################
        #                              END OF YOUR CODE                                #
        ################################################################################
        
        return x
    
    def predict(self, x):
        logits = self.forward(x)
        return F.softmax(logits)

# %%
net = ConvNet()
################################################################################
# TODO:                                                                        #
# Choose an Optimizer that will be used to minimize the loss function.         #
# Choose a critera that measures the loss                                      #
################################################################################
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
net.to(device)
criterion = nn.CrossEntropyLoss()

# %%
optimizer = optim.SGD(net.parameters(), lr=0.005, momentum=0.9)

epochs = 16
steps = 0
running_loss = 0
print_every = 20
for e in range(epochs):
    start = time.time()
    for images, labels in iter(trainloader):
        
        steps += 1
        ################################################################################
        # TODO:                                                                        #
        # Run the training process                                                     #
        #                                                                              #
        #                                                                              #
        ################################################################################
        images, labels = images.to(device), labels.to(device)
        optimizer.zero_grad()
        outputs = net(images)
        ################################################################################
        #                              END OF YOUR CODE                                #
        ################################################################################
        
        loss = criterion(outputs, labels)
        ################################################################################
        # TODO:                                                                        #
        # Run the training process                                                     #
        #                                                                              #
        # HINT: Calculate the gradient and move one step further                       #
        ################################################################################
        loss.backward()
        optimizer.step()
        ################################################################################
        #                              END OF YOUR CODE                                #
        ################################################################################
        
        running_loss += loss.item()
        
        if steps % print_every == 0:
            stop = time.time()
            # Test accuracy
            accuracy = 0
            for ii, (images, labels) in enumerate(valloader):
                
                ################################################################################
                # TODO:                                                                        #
                # Calculate the accuracy                                                       #
                ################################################################################
                with torch.no_grad():
                    images, labels = images.to(device), labels.to(device)
                    outputs = net(images)
                    _, predicted = torch.max(outputs.data, 1)
                    # alternatively
                    # _, predicted = torch.max(F.softmax(outputs,dim=1).data, 1)
                    accuracy += (predicted == labels).sum().item() / labels.size(0)
                ################################################################################
                #                              END OF YOUR CODE                                #
                ################################################################################
            
            print("Epoch: {}/{}..".format(e+1, epochs),
                  "Loss: {:.4f}..".format(running_loss/print_every),
                  "Test accuracy: {:.4f}..".format(accuracy/(ii+1)),
                  "{:.4f} s/batch".format((stop - start)/print_every)
                 )
            running_loss = 0
            start = time.time()
# 04:lr=0.001  Loss: 1.4490.. Test accuracy: 0.4340.. 0.0277 s/batch
# 08:lr=0.001  Loss: 1.3028.. Test accuracy: 0.5350.. 0.0196 s/batch
# 12:lr=0.001  Loss: 1.0942.. Test accuracy: 0.5613.. 0.0192 s/batch
# 16:lr=0.001  Loss: 0.9728.. Test accuracy: 0.6096.. 0.0204 s/batch
# 20:lr=0.001  Loss: 0.9827.. Test accuracy: 0.6143.. 0.0301 s/batch
# 28:lr=0.0005 Loss: 0.7851.. Test accuracy: 0.6361.. 0.0195 s/batch
# 32:lr=0.001  Loss: 0.7912.. Test accuracy: 0.6262.. 0.0205 s/batch
# 40:lr=0.0001 Loss: 0.6549.. Test accuracy: 0.6561.. 0.0208 s/batch
# 56:lr=0.00005L
# Out:
# Epoch: 1/16.. Loss: 0.6500.. Test accuracy: 0.6424.. 0.0339 s/batch
# Epoch: 1/16.. Loss: 0.6680.. Test accuracy: 0.6430.. 0.0214 s/batch
# Epoch: 1/16.. Loss: 0.6880.. Test accuracy: 0.6479.. 0.0200 s/batch
# Epoch: 1/16.. Loss: 0.6725.. Test accuracy: 0.6441.. 0.0354 s/batch
# Epoch: 1/16.. Loss: 0.6483.. Test accuracy: 0.6428.. 0.0212 s/batch
# Epoch: 1/16.. Loss: 0.6415.. Test accuracy: 0.6449.. 0.0206 s/batch
# Epoch: 1/16.. Loss: 0.6201.. Test accuracy: 0.6443.. 0.0202 s/batch
# Epoch: 1/16.. Loss: 0.6917.. Test accuracy: 0.6361.. 0.0199 s/batch
# Epoch: 1/16.. Loss: 0.7092.. Test accuracy: 0.6416.. 0.0206 s/batch
# Epoch: 1/16.. Loss: 0.6434.. Test accuracy: 0.6398.. 0.0210 s/batch
# Epoch: 1/16.. Loss: 0.6752.. Test accuracy: 0.6398.. 0.0206 s/batch
# Epoch: 1/16.. Loss: 0.6513.. Test accuracy: 0.6438.. 0.0208 s/batch
# Epoch: 1/16.. Loss: 0.6527.. Test accuracy: 0.6438.. 0.0206 s/batch
# Epoch: 1/16.. Loss: 0.6813.. Test accuracy: 0.6400.. 0.0212 s/batch
# Epoch: 1/16.. Loss: 0.7150.. Test accuracy: 0.6377.. 0.0202 s/batch
# Epoch: 1/16.. Loss: 0.6472.. Test accuracy: 0.6381.. 0.0207 s/batch
# Epoch: 1/16.. Loss: 0.7042.. Test accuracy: 0.6475.. 0.0206 s/batch
# Epoch: 1/16.. Loss: 0.6406.. Test accuracy: 0.6344.. 0.0206 s/batch
# Epoch: 1/16.. Loss: 0.6652.. Test accuracy: 0.6373.. 0.0195 s/batch
# Epoch: 1/16.. Loss: 0.6810.. Test accuracy: 0.6385.. 0.0197 s/batch
# Epoch: 1/16.. Loss: 0.6566.. Test accuracy: 0.6369.. 0.0200 s/batch
# Epoch: 1/16.. Loss: 0.6818.. Test accuracy: 0.6471.. 0.0206 s/batch
# Epoch: 1/16.. Loss: 0.6835.. Test accuracy: 0.6402.. 0.0209 s/batch
# Epoch: 1/16.. Loss: 0.6808.. Test accuracy: 0.6400.. 0.0206 s/batch
# Epoch: 1/16.. Loss: 0.6696.. Test accuracy: 0.6436.. 0.0200 s/batch
# Epoch: 1/16.. Loss: 0.6778.. Test accuracy: 0.6393.. 0.0208 s/batch
# Epoch: 1/16.. Loss: 0.6570.. Test accuracy: 0.6424.. 0.0195 s/batch
# Epoch: 1/16.. Loss: 0.6797.. Test accuracy: 0.6461.. 0.0207 s/batch
# Epoch: 1/16.. Loss: 0.6823.. Test accuracy: 0.6441.. 0.0204 s/batch
# Epoch: 1/16.. Loss: 0.6061.. Test accuracy: 0.6363.. 0.0199 s/batch
# Epoch: 1/16.. Loss: 0.6869.. Test accuracy: 0.6371.. 0.0197 s/batch
# Epoch: 1/16.. Loss: 0.7162.. Test accuracy: 0.6393.. 0.0202 s/batch
# Epoch: 1/16.. Loss: 0.6847.. Test accuracy: 0.6461.. 0.0200 s/batch
# Epoch: 1/16.. Loss: 0.6394.. Test accuracy: 0.6416.. 0.0206 s/batch
# Epoch: 1/16.. Loss: 0.6932.. Test accuracy: 0.6410.. 0.0204 s/batch
# Epoch: 1/16.. Loss: 0.6912.. Test accuracy: 0.6357.. 0.0202 s/batch
# Epoch: 1/16.. Loss: 0.6312.. Test accuracy: 0.6391.. 0.0207 s/batch
# Epoch: 1/16.. Loss: 0.7086.. Test accuracy: 0.6381.. 0.0203 s/batch
# Epoch: 2/16.. Loss: 0.6696.. Test accuracy: 0.6473.. 0.0275 s/batch
# Epoch: 2/16.. Loss: 0.6741.. Test accuracy: 0.6486.. 0.0202 s/batch
# Epoch: 2/16.. Loss: 0.7034.. Test accuracy: 0.6477.. 0.0198 s/batch
# Epoch: 2/16.. Loss: 0.6627.. Test accuracy: 0.6449.. 0.0209 s/batch
# Epoch: 2/16.. Loss: 0.6288.. Test accuracy: 0.6428.. 0.0206 s/batch
# Epoch: 2/16.. Loss: 0.7426.. Test accuracy: 0.6406.. 0.0201 s/batch
# Epoch: 2/16.. Loss: 0.6518.. Test accuracy: 0.6416.. 0.0202 s/batch
# Epoch: 2/16.. Loss: 0.6385.. Test accuracy: 0.6430.. 0.0204 s/batch
# Epoch: 2/16.. Loss: 0.6459.. Test accuracy: 0.6434.. 0.0201 s/batch
# Epoch: 2/16.. Loss: 0.6829.. Test accuracy: 0.6402.. 0.0208 s/batch
# Epoch: 2/16.. Loss: 0.6644.. Test accuracy: 0.6406.. 0.0208 s/batch
# Epoch: 2/16.. Loss: 0.6681.. Test accuracy: 0.6430.. 0.0208 s/batch
# Epoch: 2/16.. Loss: 0.6611.. Test accuracy: 0.6400.. 0.0199 s/batch
# Epoch: 2/16.. Loss: 0.6811.. Test accuracy: 0.6465.. 0.0203 s/batch
# Epoch: 2/16.. Loss: 0.6532.. Test accuracy: 0.6393.. 0.0201 s/batch
# Epoch: 2/16.. Loss: 0.6330.. Test accuracy: 0.6422.. 0.0206 s/batch
# Epoch: 2/16.. Loss: 0.6678.. Test accuracy: 0.6447.. 0.0210 s/batch
# Epoch: 2/16.. Loss: 0.6765.. Test accuracy: 0.6436.. 0.0195 s/batch
# Epoch: 2/16.. Loss: 0.6891.. Test accuracy: 0.6494.. 0.0204 s/batch
# Epoch: 2/16.. Loss: 0.6626.. Test accuracy: 0.6451.. 0.0197 s/batch
# Epoch: 2/16.. Loss: 0.6523.. Test accuracy: 0.6418.. 0.0203 s/batch
# Epoch: 2/16.. Loss: 0.7027.. Test accuracy: 0.6346.. 0.0206 s/batch
# Epoch: 2/16.. Loss: 0.6641.. Test accuracy: 0.6342.. 0.0203 s/batch
# Epoch: 2/16.. Loss: 0.6776.. Test accuracy: 0.6400.. 0.0200 s/batch
# Epoch: 2/16.. Loss: 0.6509.. Test accuracy: 0.6451.. 0.0200 s/batch
# Epoch: 2/16.. Loss: 0.6318.. Test accuracy: 0.6441.. 0.0212 s/batch
# Epoch: 2/16.. Loss: 0.6742.. Test accuracy: 0.6412.. 0.0198 s/batch
# Epoch: 2/16.. Loss: 0.6787.. Test accuracy: 0.6307.. 0.0200 s/batch
# Epoch: 2/16.. Loss: 0.6892.. Test accuracy: 0.6346.. 0.0203 s/batch
# Epoch: 2/16.. Loss: 0.7060.. Test accuracy: 0.6439.. 0.0191 s/batch
# Epoch: 2/16.. Loss: 0.6606.. Test accuracy: 0.6449.. 0.0203 s/batch
# Epoch: 2/16.. Loss: 0.6707.. Test accuracy: 0.6406.. 0.0198 s/batch
# Epoch: 2/16.. Loss: 0.6799.. Test accuracy: 0.6367.. 0.0207 s/batch
# Epoch: 2/16.. Loss: 0.6663.. Test accuracy: 0.6355.. 0.0201 s/batch
# Epoch: 2/16.. Loss: 0.6570.. Test accuracy: 0.6414.. 0.0209 s/batch
# Epoch: 2/16.. Loss: 0.6774.. Test accuracy: 0.6379.. 0.0202 s/batch
# Epoch: 2/16.. Loss: 0.6326.. Test accuracy: 0.6393.. 0.0198 s/batch
# Epoch: 2/16.. Loss: 0.7280.. Test accuracy: 0.6395.. 0.0196 s/batch
# Epoch: 3/16.. Loss: 0.6503.. Test accuracy: 0.6445.. 0.0156 s/batch
# Epoch: 3/16.. Loss: 0.6405.. Test accuracy: 0.6398.. 0.0197 s/batch
# Epoch: 3/16.. Loss: 0.6268.. Test accuracy: 0.6416.. 0.0204 s/batch
# Epoch: 3/16.. Loss: 0.7103.. Test accuracy: 0.6453.. 0.0203 s/batch
# Epoch: 3/16.. Loss: 0.6758.. Test accuracy: 0.6434.. 0.0208 s/batch
# Epoch: 3/16.. Loss: 0.6599.. Test accuracy: 0.6441.. 0.0198 s/batch
# Epoch: 3/16.. Loss: 0.6423.. Test accuracy: 0.6420.. 0.0197 s/batch
# Epoch: 3/16.. Loss: 0.6875.. Test accuracy: 0.6414.. 0.0187 s/batch
# Epoch: 3/16.. Loss: 0.6608.. Test accuracy: 0.6414.. 0.0205 s/batch
# Epoch: 3/16.. Loss: 0.6727.. Test accuracy: 0.6416.. 0.0206 s/batch
# Epoch: 3/16.. Loss: 0.6864.. Test accuracy: 0.6492.. 0.0193 s/batch
# Epoch: 3/16.. Loss: 0.6990.. Test accuracy: 0.6412.. 0.0202 s/batch
# Epoch: 3/16.. Loss: 0.6424.. Test accuracy: 0.6373.. 0.0192 s/batch
# Epoch: 3/16.. Loss: 0.6730.. Test accuracy: 0.6389.. 0.0199 s/batch
# Epoch: 3/16.. Loss: 0.6308.. Test accuracy: 0.6422.. 0.0200 s/batch
# Epoch: 3/16.. Loss: 0.6631.. Test accuracy: 0.6396.. 0.0197 s/batch
# Epoch: 3/16.. Loss: 0.6573.. Test accuracy: 0.6406.. 0.0196 s/batch
# Epoch: 3/16.. Loss: 0.6797.. Test accuracy: 0.6441.. 0.0195 s/batch
# Epoch: 3/16.. Loss: 0.6828.. Test accuracy: 0.6441.. 0.0202 s/batch
# Epoch: 3/16.. Loss: 0.6602.. Test accuracy: 0.6424.. 0.0201 s/batch
# Epoch: 3/16.. Loss: 0.6702.. Test accuracy: 0.6445.. 0.0192 s/batch
# Epoch: 3/16.. Loss: 0.6694.. Test accuracy: 0.6396.. 0.0200 s/batch
# Epoch: 3/16.. Loss: 0.6982.. Test accuracy: 0.6414.. 0.0209 s/batch
# Epoch: 3/16.. Loss: 0.6594.. Test accuracy: 0.6381.. 0.0196 s/batch
# Epoch: 3/16.. Loss: 0.6327.. Test accuracy: 0.6387.. 0.0199 s/batch
# Epoch: 3/16.. Loss: 0.6664.. Test accuracy: 0.6363.. 0.0208 s/batch
# Epoch: 3/16.. Loss: 0.6458.. Test accuracy: 0.6396.. 0.0195 s/batch
# Epoch: 3/16.. Loss: 0.7352.. Test accuracy: 0.6367.. 0.0196 s/batch
# Epoch: 3/16.. Loss: 0.6779.. Test accuracy: 0.6344.. 0.0200 s/batch
# Epoch: 3/16.. Loss: 0.6113.. Test accuracy: 0.6418.. 0.0196 s/batch
# Epoch: 3/16.. Loss: 0.6497.. Test accuracy: 0.6447.. 0.0198 s/batch
# Epoch: 3/16.. Loss: 0.7173.. Test accuracy: 0.6473.. 0.0207 s/batch
# Epoch: 3/16.. Loss: 0.6437.. Test accuracy: 0.6475.. 0.0211 s/batch
# Epoch: 3/16.. Loss: 0.7208.. Test accuracy: 0.6445.. 0.0197 s/batch
# Epoch: 3/16.. Loss: 0.6747.. Test accuracy: 0.6455.. 0.0204 s/batch
# Epoch: 3/16.. Loss: 0.6619.. Test accuracy: 0.6404.. 0.0207 s/batch
# Epoch: 3/16.. Loss: 0.6932.. Test accuracy: 0.6414.. 0.0206 s/batch
# Epoch: 3/16.. Loss: 0.6838.. Test accuracy: 0.6381.. 0.0199 s/batch
# Epoch: 4/16.. Loss: 0.6115.. Test accuracy: 0.6414.. 0.0093 s/batch
# Epoch: 4/16.. Loss: 0.6835.. Test accuracy: 0.6434.. 0.0200 s/batch
# Epoch: 4/16.. Loss: 0.6235.. Test accuracy: 0.6396.. 0.0185 s/batch
# Epoch: 4/16.. Loss: 0.6515.. Test accuracy: 0.6506.. 0.0199 s/batch
# Epoch: 4/16.. Loss: 0.7002.. Test accuracy: 0.6477.. 0.0199 s/batch
# Epoch: 4/16.. Loss: 0.6451.. Test accuracy: 0.6430.. 0.0204 s/batch
# Epoch: 4/16.. Loss: 0.6898.. Test accuracy: 0.6418.. 0.0201 s/batch
# Epoch: 4/16.. Loss: 0.6632.. Test accuracy: 0.6443.. 0.0201 s/batch
# Epoch: 4/16.. Loss: 0.6694.. Test accuracy: 0.6434.. 0.0208 s/batch
# Epoch: 4/16.. Loss: 0.6647.. Test accuracy: 0.6457.. 0.0204 s/batch
# Epoch: 4/16.. Loss: 0.6765.. Test accuracy: 0.6404.. 0.0221 s/batch
# Epoch: 4/16.. Loss: 0.6858.. Test accuracy: 0.6379.. 0.0206 s/batch
# Epoch: 4/16.. Loss: 0.6662.. Test accuracy: 0.6428.. 0.0206 s/batch
# Epoch: 4/16.. Loss: 0.6892.. Test accuracy: 0.6434.. 0.0207 s/batch
# Epoch: 4/16.. Loss: 0.6104.. Test accuracy: 0.6387.. 0.0210 s/batch
# Epoch: 4/16.. Loss: 0.7291.. Test accuracy: 0.6408.. 0.0202 s/batch
# Epoch: 4/16.. Loss: 0.6842.. Test accuracy: 0.6428.. 0.0199 s/batch
# Epoch: 4/16.. Loss: 0.7404.. Test accuracy: 0.6451.. 0.0207 s/batch
# Epoch: 4/16.. Loss: 0.6589.. Test accuracy: 0.6459.. 0.0201 s/batch
# Epoch: 4/16.. Loss: 0.6893.. Test accuracy: 0.6416.. 0.0199 s/batch
# Epoch: 4/16.. Loss: 0.6492.. Test accuracy: 0.6465.. 0.0216 s/batch
# Epoch: 4/16.. Loss: 0.6897.. Test accuracy: 0.6508.. 0.0201 s/batch
# Epoch: 4/16.. Loss: 0.6654.. Test accuracy: 0.6443.. 0.0199 s/batch
# Epoch: 4/16.. Loss: 0.6505.. Test accuracy: 0.6367.. 0.0202 s/batch
# Epoch: 4/16.. Loss: 0.6445.. Test accuracy: 0.6416.. 0.0203 s/batch
# Epoch: 4/16.. Loss: 0.6094.. Test accuracy: 0.6391.. 0.0200 s/batch
# Epoch: 4/16.. Loss: 0.6782.. Test accuracy: 0.6420.. 0.0192 s/batch
# Epoch: 4/16.. Loss: 0.6461.. Test accuracy: 0.6461.. 0.0196 s/batch
# Epoch: 4/16.. Loss: 0.6600.. Test accuracy: 0.6383.. 0.0202 s/batch
# Epoch: 4/16.. Loss: 0.6633.. Test accuracy: 0.6359.. 0.0207 s/batch
# Epoch: 4/16.. Loss: 0.6335.. Test accuracy: 0.6391.. 0.0209 s/batch
# Epoch: 4/16.. Loss: 0.6824.. Test accuracy: 0.6449.. 0.0200 s/batch
# Epoch: 4/16.. Loss: 0.6751.. Test accuracy: 0.6365.. 0.0202 s/batch
# Epoch: 4/16.. Loss: 0.6521.. Test accuracy: 0.6385.. 0.0217 s/batch
# Epoch: 4/16.. Loss: 0.6835.. Test accuracy: 0.6395.. 0.0198 s/batch
# Epoch: 4/16.. Loss: 0.6528.. Test accuracy: 0.6432.. 0.0211 s/batch
# Epoch: 4/16.. Loss: 0.6824.. Test accuracy: 0.6428.. 0.0221 s/batch
# Epoch: 4/16.. Loss: 0.6550.. Test accuracy: 0.6385.. 0.0235 s/batch
# Epoch: 4/16.. Loss: 0.6464.. Test accuracy: 0.6369.. 0.0287 s/batch
# Epoch: 5/16.. Loss: 0.6311.. Test accuracy: 0.6416.. 0.0307 s/batch
# Epoch: 5/16.. Loss: 0.6403.. Test accuracy: 0.6406.. 0.0213 s/batch
# Epoch: 5/16.. Loss: 0.7013.. Test accuracy: 0.6379.. 0.0204 s/batch
# Epoch: 5/16.. Loss: 0.6416.. Test accuracy: 0.6451.. 0.0197 s/batch
# Epoch: 5/16.. Loss: 0.6318.. Test accuracy: 0.6420.. 0.0202 s/batch
# Epoch: 5/16.. Loss: 0.6710.. Test accuracy: 0.6391.. 0.0204 s/batch
# Epoch: 5/16.. Loss: 0.6564.. Test accuracy: 0.6381.. 0.0207 s/batch
# Epoch: 5/16.. Loss: 0.6200.. Test accuracy: 0.6359.. 0.0211 s/batch
# Epoch: 5/16.. Loss: 0.6948.. Test accuracy: 0.6326.. 0.0208 s/batch
# Epoch: 5/16.. Loss: 0.6760.. Test accuracy: 0.6391.. 0.0200 s/batch
# Epoch: 5/16.. Loss: 0.6529.. Test accuracy: 0.6396.. 0.0205 s/batch
# Epoch: 5/16.. Loss: 0.6443.. Test accuracy: 0.6395.. 0.0207 s/batch
# Epoch: 5/16.. Loss: 0.6075.. Test accuracy: 0.6445.. 0.0208 s/batch
# Epoch: 5/16.. Loss: 0.6630.. Test accuracy: 0.6471.. 0.0207 s/batch
# Epoch: 5/16.. Loss: 0.7052.. Test accuracy: 0.6477.. 0.0214 s/batch
# Epoch: 5/16.. Loss: 0.6225.. Test accuracy: 0.6479.. 0.0206 s/batch
# Epoch: 5/16.. Loss: 0.6377.. Test accuracy: 0.6449.. 0.0264 s/batch
# Epoch: 5/16.. Loss: 0.6794.. Test accuracy: 0.6402.. 0.0205 s/batch
# Epoch: 5/16.. Loss: 0.6787.. Test accuracy: 0.6445.. 0.0206 s/batch
# Epoch: 5/16.. Loss: 0.6593.. Test accuracy: 0.6408.. 0.0204 s/batch
# Epoch: 5/16.. Loss: 0.6809.. Test accuracy: 0.6393.. 0.0208 s/batch
# Epoch: 5/16.. Loss: 0.6712.. Test accuracy: 0.6412.. 0.0202 s/batch
# Epoch: 5/16.. Loss: 0.6691.. Test accuracy: 0.6424.. 0.0206 s/batch
# Epoch: 5/16.. Loss: 0.6540.. Test accuracy: 0.6385.. 0.0209 s/batch
# Epoch: 5/16.. Loss: 0.6654.. Test accuracy: 0.6400.. 0.0205 s/batch
# Epoch: 5/16.. Loss: 0.6876.. Test accuracy: 0.6451.. 0.0201 s/batch
# Epoch: 5/16.. Loss: 0.7034.. Test accuracy: 0.6398.. 0.0204 s/batch
# Epoch: 5/16.. Loss: 0.6785.. Test accuracy: 0.6420.. 0.0206 s/batch
# Epoch: 5/16.. Loss: 0.6643.. Test accuracy: 0.6395.. 0.0208 s/batch
# Epoch: 5/16.. Loss: 0.6890.. Test accuracy: 0.6434.. 0.0199 s/batch
# Epoch: 5/16.. Loss: 0.6922.. Test accuracy: 0.6463.. 0.0202 s/batch
# Epoch: 5/16.. Loss: 0.6700.. Test accuracy: 0.6477.. 0.0200 s/batch
# Epoch: 5/16.. Loss: 0.6935.. Test accuracy: 0.6420.. 0.0205 s/batch
# Epoch: 5/16.. Loss: 0.6729.. Test accuracy: 0.6373.. 0.0214 s/batch
# Epoch: 5/16.. Loss: 0.6894.. Test accuracy: 0.6441.. 0.0217 s/batch
# Epoch: 5/16.. Loss: 0.6538.. Test accuracy: 0.6445.. 0.0216 s/batch
# Epoch: 5/16.. Loss: 0.6447.. Test accuracy: 0.6434.. 0.0212 s/batch
# Epoch: 5/16.. Loss: 0.6897.. Test accuracy: 0.6424.. 0.0203 s/batch
# Epoch: 6/16.. Loss: 0.6589.. Test accuracy: 0.6469.. 0.0247 s/batch
# Epoch: 6/16.. Loss: 0.6888.. Test accuracy: 0.6430.. 0.0203 s/batch
# Epoch: 6/16.. Loss: 0.6784.. Test accuracy: 0.6443.. 0.0201 s/batch
# Epoch: 6/16.. Loss: 0.5977.. Test accuracy: 0.6457.. 0.0203 s/batch
# Epoch: 6/16.. Loss: 0.6894.. Test accuracy: 0.6469.. 0.0209 s/batch
# Epoch: 6/16.. Loss: 0.6559.. Test accuracy: 0.6484.. 0.0211 s/batch
# Epoch: 6/16.. Loss: 0.6916.. Test accuracy: 0.6537.. 0.0209 s/batch
# Epoch: 6/16.. Loss: 0.6465.. Test accuracy: 0.6480.. 0.0202 s/batch
# Epoch: 6/16.. Loss: 0.6901.. Test accuracy: 0.6453.. 0.0205 s/batch
# Epoch: 6/16.. Loss: 0.6398.. Test accuracy: 0.6492.. 0.0204 s/batch
# Epoch: 6/16.. Loss: 0.6394.. Test accuracy: 0.6453.. 0.0205 s/batch
# Epoch: 6/16.. Loss: 0.6771.. Test accuracy: 0.6410.. 0.0213 s/batch
# Epoch: 6/16.. Loss: 0.6501.. Test accuracy: 0.6375.. 0.0210 s/batch
# Epoch: 6/16.. Loss: 0.6316.. Test accuracy: 0.6473.. 0.0205 s/batch
# Epoch: 6/16.. Loss: 0.6607.. Test accuracy: 0.6453.. 0.0206 s/batch
# Epoch: 6/16.. Loss: 0.6765.. Test accuracy: 0.6426.. 0.0206 s/batch
# Epoch: 6/16.. Loss: 0.7050.. Test accuracy: 0.6461.. 0.0210 s/batch
# Epoch: 6/16.. Loss: 0.6511.. Test accuracy: 0.6402.. 0.0221 s/batch
# Epoch: 6/16.. Loss: 0.6580.. Test accuracy: 0.6406.. 0.0217 s/batch
# Epoch: 6/16.. Loss: 0.6862.. Test accuracy: 0.6404.. 0.0214 s/batch
# Epoch: 6/16.. Loss: 0.6600.. Test accuracy: 0.6424.. 0.0212 s/batch
# Epoch: 6/16.. Loss: 0.7015.. Test accuracy: 0.6404.. 0.0206 s/batch
# Epoch: 6/16.. Loss: 0.6309.. Test accuracy: 0.6432.. 0.0203 s/batch
# Epoch: 6/16.. Loss: 0.6704.. Test accuracy: 0.6406.. 0.0211 s/batch
# Epoch: 6/16.. Loss: 0.6604.. Test accuracy: 0.6422.. 0.0208 s/batch
# Epoch: 6/16.. Loss: 0.6544.. Test accuracy: 0.6383.. 0.0204 s/batch
# Epoch: 6/16.. Loss: 0.6582.. Test accuracy: 0.6387.. 0.0209 s/batch
# Epoch: 6/16.. Loss: 0.6900.. Test accuracy: 0.6367.. 0.0207 s/batch
# Epoch: 6/16.. Loss: 0.6682.. Test accuracy: 0.6420.. 0.0208 s/batch
# Epoch: 6/16.. Loss: 0.6292.. Test accuracy: 0.6414.. 0.0208 s/batch
# Epoch: 6/16.. Loss: 0.6640.. Test accuracy: 0.6463.. 0.0204 s/batch
# Epoch: 6/16.. Loss: 0.6508.. Test accuracy: 0.6408.. 0.0203 s/batch
# Epoch: 6/16.. Loss: 0.6901.. Test accuracy: 0.6385.. 0.0209 s/batch
# Epoch: 6/16.. Loss: 0.6562.. Test accuracy: 0.6408.. 0.0214 s/batch
# Epoch: 6/16.. Loss: 0.6671.. Test accuracy: 0.6463.. 0.0209 s/batch
# Epoch: 6/16.. Loss: 0.6192.. Test accuracy: 0.6434.. 0.0199 s/batch
# Epoch: 6/16.. Loss: 0.6550.. Test accuracy: 0.6445.. 0.0199 s/batch
# Epoch: 6/16.. Loss: 0.6856.. Test accuracy: 0.6496.. 0.0209 s/batch
# Epoch: 7/16.. Loss: 0.6700.. Test accuracy: 0.6416.. 0.0172 s/batch
# Epoch: 7/16.. Loss: 0.6282.. Test accuracy: 0.6434.. 0.0200 s/batch
# Epoch: 7/16.. Loss: 0.6324.. Test accuracy: 0.6418.. 0.0205 s/batch
# Epoch: 7/16.. Loss: 0.6142.. Test accuracy: 0.6426.. 0.0203 s/batch
# Epoch: 7/16.. Loss: 0.6984.. Test accuracy: 0.6387.. 0.0210 s/batch
# Epoch: 7/16.. Loss: 0.6661.. Test accuracy: 0.6410.. 0.0202 s/batch
# Epoch: 7/16.. Loss: 0.6606.. Test accuracy: 0.6420.. 0.0207 s/batch
# Epoch: 7/16.. Loss: 0.7330.. Test accuracy: 0.6416.. 0.0202 s/batch
# Epoch: 7/16.. Loss: 0.6906.. Test accuracy: 0.6346.. 0.0206 s/batch
# Epoch: 7/16.. Loss: 0.6781.. Test accuracy: 0.6383.. 0.0210 s/batch
# Epoch: 7/16.. Loss: 0.6442.. Test accuracy: 0.6438.. 0.0217 s/batch
# Epoch: 7/16.. Loss: 0.6789.. Test accuracy: 0.6422.. 0.0207 s/batch
# Epoch: 7/16.. Loss: 0.6430.. Test accuracy: 0.6453.. 0.0205 s/batch
# Epoch: 7/16.. Loss: 0.6744.. Test accuracy: 0.6357.. 0.0207 s/batch
# Epoch: 7/16.. Loss: 0.6519.. Test accuracy: 0.6393.. 0.0206 s/batch
# Epoch: 7/16.. Loss: 0.6774.. Test accuracy: 0.6430.. 0.0213 s/batch
# Epoch: 7/16.. Loss: 0.6277.. Test accuracy: 0.6422.. 0.0210 s/batch
# Epoch: 7/16.. Loss: 0.7068.. Test accuracy: 0.6434.. 0.0208 s/batch
# Epoch: 7/16.. Loss: 0.6230.. Test accuracy: 0.6439.. 0.0208 s/batch
# Epoch: 7/16.. Loss: 0.6684.. Test accuracy: 0.6383.. 0.0211 s/batch
# Epoch: 7/16.. Loss: 0.6784.. Test accuracy: 0.6508.. 0.0204 s/batch
# Epoch: 7/16.. Loss: 0.6412.. Test accuracy: 0.6510.. 0.0204 s/batch
# Epoch: 7/16.. Loss: 0.6032.. Test accuracy: 0.6475.. 0.0216 s/batch
# Epoch: 7/16.. Loss: 0.6747.. Test accuracy: 0.6473.. 0.0202 s/batch
# Epoch: 7/16.. Loss: 0.6780.. Test accuracy: 0.6494.. 0.0204 s/batch
# Epoch: 7/16.. Loss: 0.6859.. Test accuracy: 0.6459.. 0.0198 s/batch
# Epoch: 7/16.. Loss: 0.7024.. Test accuracy: 0.6531.. 0.0197 s/batch
# Epoch: 7/16.. Loss: 0.6497.. Test accuracy: 0.6387.. 0.0206 s/batch
# Epoch: 7/16.. Loss: 0.6676.. Test accuracy: 0.6432.. 0.0203 s/batch
# Epoch: 7/16.. Loss: 0.6572.. Test accuracy: 0.6457.. 0.0208 s/batch
# Epoch: 7/16.. Loss: 0.6585.. Test accuracy: 0.6428.. 0.0206 s/batch
# Epoch: 7/16.. Loss: 0.6793.. Test accuracy: 0.6420.. 0.0201 s/batch
# Epoch: 7/16.. Loss: 0.6609.. Test accuracy: 0.6404.. 0.0198 s/batch
# Epoch: 7/16.. Loss: 0.6798.. Test accuracy: 0.6438.. 0.0199 s/batch
# Epoch: 7/16.. Loss: 0.5929.. Test accuracy: 0.6387.. 0.0206 s/batch
# Epoch: 7/16.. Loss: 0.6472.. Test accuracy: 0.6414.. 0.0216 s/batch
# Epoch: 7/16.. Loss: 0.6350.. Test accuracy: 0.6523.. 0.0207 s/batch
# Epoch: 7/16.. Loss: 0.7084.. Test accuracy: 0.6393.. 0.0201 s/batch
# Epoch: 7/16.. Loss: 0.6838.. Test accuracy: 0.6379.. 0.0221 s/batch
# Epoch: 8/16.. Loss: 0.6711.. Test accuracy: 0.6400.. 0.0269 s/batch
# Epoch: 8/16.. Loss: 0.6487.. Test accuracy: 0.6359.. 0.0209 s/batch
# Epoch: 8/16.. Loss: 0.6732.. Test accuracy: 0.6334.. 0.0203 s/batch
# Epoch: 8/16.. Loss: 0.6331.. Test accuracy: 0.6420.. 0.0205 s/batch
# Epoch: 8/16.. Loss: 0.6799.. Test accuracy: 0.6396.. 0.0210 s/batch
# Epoch: 8/16.. Loss: 0.6556.. Test accuracy: 0.6420.. 0.0215 s/batch
# Epoch: 8/16.. Loss: 0.6943.. Test accuracy: 0.6438.. 0.0213 s/batch
# Epoch: 8/16.. Loss: 0.6477.. Test accuracy: 0.6391.. 0.0205 s/batch
# Epoch: 8/16.. Loss: 0.6327.. Test accuracy: 0.6396.. 0.0211 s/batch
# Epoch: 8/16.. Loss: 0.6574.. Test accuracy: 0.6402.. 0.0202 s/batch
# Epoch: 8/16.. Loss: 0.6571.. Test accuracy: 0.6508.. 0.0203 s/batch
# Epoch: 8/16.. Loss: 0.6392.. Test accuracy: 0.6471.. 0.0214 s/batch
# Epoch: 8/16.. Loss: 0.6566.. Test accuracy: 0.6438.. 0.0204 s/batch
# Epoch: 8/16.. Loss: 0.6735.. Test accuracy: 0.6510.. 0.0196 s/batch
# Epoch: 8/16.. Loss: 0.6658.. Test accuracy: 0.6426.. 0.0208 s/batch
# Epoch: 8/16.. Loss: 0.5854.. Test accuracy: 0.6457.. 0.0197 s/batch
# Epoch: 8/16.. Loss: 0.6530.. Test accuracy: 0.6436.. 0.0204 s/batch
# Epoch: 8/16.. Loss: 0.7165.. Test accuracy: 0.6418.. 0.0209 s/batch
# Epoch: 8/16.. Loss: 0.6783.. Test accuracy: 0.6418.. 0.0205 s/batch
# Epoch: 8/16.. Loss: 0.6645.. Test accuracy: 0.6441.. 0.0195 s/batch
# Epoch: 8/16.. Loss: 0.6454.. Test accuracy: 0.6320.. 0.0202 s/batch
# Epoch: 8/16.. Loss: 0.6901.. Test accuracy: 0.6412.. 0.0199 s/batch
# Epoch: 8/16.. Loss: 0.6375.. Test accuracy: 0.6434.. 0.0211 s/batch
# Epoch: 8/16.. Loss: 0.6161.. Test accuracy: 0.6369.. 0.0199 s/batch
# Epoch: 8/16.. Loss: 0.6637.. Test accuracy: 0.6377.. 0.0210 s/batch
# Epoch: 8/16.. Loss: 0.6088.. Test accuracy: 0.6385.. 0.0197 s/batch
# Epoch: 8/16.. Loss: 0.6785.. Test accuracy: 0.6395.. 0.0202 s/batch
# Epoch: 8/16.. Loss: 0.7140.. Test accuracy: 0.6420.. 0.0202 s/batch
# Epoch: 8/16.. Loss: 0.6991.. Test accuracy: 0.6391.. 0.0199 s/batch
# Epoch: 8/16.. Loss: 0.6431.. Test accuracy: 0.6412.. 0.0205 s/batch
# Epoch: 8/16.. Loss: 0.6329.. Test accuracy: 0.6455.. 0.0202 s/batch
# Epoch: 8/16.. Loss: 0.6342.. Test accuracy: 0.6488.. 0.0204 s/batch
# Epoch: 8/16.. Loss: 0.6430.. Test accuracy: 0.6449.. 0.0201 s/batch
# Epoch: 8/16.. Loss: 0.7116.. Test accuracy: 0.6393.. 0.0198 s/batch
# Epoch: 8/16.. Loss: 0.6370.. Test accuracy: 0.6486.. 0.0203 s/batch
# Epoch: 8/16.. Loss: 0.7059.. Test accuracy: 0.6488.. 0.0219 s/batch
# Epoch: 8/16.. Loss: 0.6788.. Test accuracy: 0.6479.. 0.0214 s/batch
# Epoch: 8/16.. Loss: 0.6644.. Test accuracy: 0.6498.. 0.0205 s/batch
# Epoch: 9/16.. Loss: 0.6759.. Test accuracy: 0.6514.. 0.0208 s/batch
# Epoch: 9/16.. Loss: 0.7061.. Test accuracy: 0.6486.. 0.0199 s/batch
# Epoch: 9/16.. Loss: 0.6315.. Test accuracy: 0.6506.. 0.0192 s/batch
# Epoch: 9/16.. Loss: 0.6612.. Test accuracy: 0.6465.. 0.0197 s/batch
# Epoch: 9/16.. Loss: 0.6649.. Test accuracy: 0.6486.. 0.0200 s/batch
# Epoch: 9/16.. Loss: 0.6234.. Test accuracy: 0.6443.. 0.0204 s/batch
# Epoch: 9/16.. Loss: 0.6889.. Test accuracy: 0.6406.. 0.0207 s/batch
# Epoch: 9/16.. Loss: 0.6101.. Test accuracy: 0.6457.. 0.0205 s/batch
# Epoch: 9/16.. Loss: 0.6306.. Test accuracy: 0.6416.. 0.0196 s/batch
# Epoch: 9/16.. Loss: 0.6371.. Test accuracy: 0.6434.. 0.0202 s/batch
# Epoch: 9/16.. Loss: 0.6387.. Test accuracy: 0.6447.. 0.0206 s/batch
# Epoch: 9/16.. Loss: 0.6356.. Test accuracy: 0.6381.. 0.0205 s/batch
# Epoch: 9/16.. Loss: 0.6459.. Test accuracy: 0.6408.. 0.0206 s/batch
# Epoch: 9/16.. Loss: 0.6600.. Test accuracy: 0.6467.. 0.0211 s/batch
# Epoch: 9/16.. Loss: 0.6781.. Test accuracy: 0.6518.. 0.0198 s/batch
# Epoch: 9/16.. Loss: 0.6290.. Test accuracy: 0.6449.. 0.0196 s/batch
# Epoch: 9/16.. Loss: 0.6133.. Test accuracy: 0.6404.. 0.0202 s/batch
# Epoch: 9/16.. Loss: 0.6546.. Test accuracy: 0.6402.. 0.0200 s/batch
# Epoch: 9/16.. Loss: 0.6501.. Test accuracy: 0.6398.. 0.0211 s/batch
# Epoch: 9/16.. Loss: 0.6504.. Test accuracy: 0.6473.. 0.0217 s/batch
# Epoch: 9/16.. Loss: 0.6873.. Test accuracy: 0.6412.. 0.0205 s/batch
# Epoch: 9/16.. Loss: 0.6955.. Test accuracy: 0.6418.. 0.0205 s/batch
# Epoch: 9/16.. Loss: 0.6485.. Test accuracy: 0.6480.. 0.0203 s/batch
# Epoch: 9/16.. Loss: 0.6696.. Test accuracy: 0.6471.. 0.0197 s/batch
# Epoch: 9/16.. Loss: 0.6472.. Test accuracy: 0.6445.. 0.0207 s/batch
# Epoch: 9/16.. Loss: 0.6948.. Test accuracy: 0.6465.. 0.0202 s/batch
# Epoch: 9/16.. Loss: 0.6781.. Test accuracy: 0.6340.. 0.0203 s/batch
# Epoch: 9/16.. Loss: 0.6528.. Test accuracy: 0.6393.. 0.0199 s/batch
# Epoch: 9/16.. Loss: 0.6581.. Test accuracy: 0.6453.. 0.0205 s/batch
# Epoch: 9/16.. Loss: 0.7049.. Test accuracy: 0.6453.. 0.0205 s/batch
# Epoch: 9/16.. Loss: 0.6526.. Test accuracy: 0.6467.. 0.0206 s/batch
# Epoch: 9/16.. Loss: 0.6518.. Test accuracy: 0.6502.. 0.0207 s/batch
# Epoch: 9/16.. Loss: 0.6855.. Test accuracy: 0.6453.. 0.0203 s/batch
# Epoch: 9/16.. Loss: 0.6777.. Test accuracy: 0.6467.. 0.0204 s/batch
# Epoch: 9/16.. Loss: 0.6719.. Test accuracy: 0.6467.. 0.0205 s/batch
# Epoch: 9/16.. Loss: 0.6955.. Test accuracy: 0.6428.. 0.0200 s/batch
# Epoch: 9/16.. Loss: 0.6849.. Test accuracy: 0.6414.. 0.0198 s/batch
# Epoch: 9/16.. Loss: 0.6720.. Test accuracy: 0.6361.. 0.0208 s/batch
# Epoch: 10/16.. Loss: 0.6444.. Test accuracy: 0.6410.. 0.0195 s/batch
# Epoch: 10/16.. Loss: 0.6627.. Test accuracy: 0.6455.. 0.0210 s/batch
# Epoch: 10/16.. Loss: 0.6358.. Test accuracy: 0.6457.. 0.0203 s/batch
# Epoch: 10/16.. Loss: 0.6973.. Test accuracy: 0.6514.. 0.0195 s/batch
# Epoch: 10/16.. Loss: 0.6700.. Test accuracy: 0.6410.. 0.0199 s/batch
# Epoch: 10/16.. Loss: 0.6733.. Test accuracy: 0.6426.. 0.0199 s/batch
# Epoch: 10/16.. Loss: 0.6436.. Test accuracy: 0.6488.. 0.0207 s/batch
# Epoch: 10/16.. Loss: 0.6454.. Test accuracy: 0.6430.. 0.0210 s/batch
# Epoch: 10/16.. Loss: 0.6362.. Test accuracy: 0.6445.. 0.0208 s/batch
# Epoch: 10/16.. Loss: 0.6320.. Test accuracy: 0.6416.. 0.0197 s/batch
# Epoch: 10/16.. Loss: 0.6768.. Test accuracy: 0.6436.. 0.0207 s/batch
# Epoch: 10/16.. Loss: 0.6704.. Test accuracy: 0.6418.. 0.0203 s/batch
# Epoch: 10/16.. Loss: 0.6566.. Test accuracy: 0.6459.. 0.0204 s/batch
# Epoch: 10/16.. Loss: 0.6832.. Test accuracy: 0.6523.. 0.0203 s/batch
# Epoch: 10/16.. Loss: 0.6581.. Test accuracy: 0.6459.. 0.0205 s/batch
# Epoch: 10/16.. Loss: 0.6828.. Test accuracy: 0.6457.. 0.0210 s/batch
# Epoch: 10/16.. Loss: 0.6152.. Test accuracy: 0.6490.. 0.0203 s/batch
# Epoch: 10/16.. Loss: 0.6452.. Test accuracy: 0.6441.. 0.0202 s/batch
# Epoch: 10/16.. Loss: 0.6318.. Test accuracy: 0.6465.. 0.0196 s/batch
# Epoch: 10/16.. Loss: 0.6265.. Test accuracy: 0.6531.. 0.0216 s/batch
# Epoch: 10/16.. Loss: 0.6456.. Test accuracy: 0.6430.. 0.0207 s/batch
# Epoch: 10/16.. Loss: 0.6242.. Test accuracy: 0.6420.. 0.0209 s/batch
# Epoch: 10/16.. Loss: 0.6534.. Test accuracy: 0.6467.. 0.0204 s/batch
# Epoch: 10/16.. Loss: 0.6905.. Test accuracy: 0.6482.. 0.0197 s/batch
# Epoch: 10/16.. Loss: 0.6586.. Test accuracy: 0.6465.. 0.0200 s/batch
# Epoch: 10/16.. Loss: 0.6566.. Test accuracy: 0.6461.. 0.0206 s/batch
# Epoch: 10/16.. Loss: 0.6571.. Test accuracy: 0.6412.. 0.0205 s/batch
# Epoch: 10/16.. Loss: 0.6466.. Test accuracy: 0.6482.. 0.0212 s/batch
# Epoch: 10/16.. Loss: 0.6340.. Test accuracy: 0.6477.. 0.0195 s/batch
# Epoch: 10/16.. Loss: 0.6726.. Test accuracy: 0.6434.. 0.0197 s/batch
# Epoch: 10/16.. Loss: 0.6702.. Test accuracy: 0.6420.. 0.0200 s/batch
# Epoch: 10/16.. Loss: 0.6563.. Test accuracy: 0.6414.. 0.0206 s/batch
# Epoch: 10/16.. Loss: 0.6346.. Test accuracy: 0.6385.. 0.0206 s/batch
# Epoch: 10/16.. Loss: 0.6601.. Test accuracy: 0.6443.. 0.0207 s/batch
# Epoch: 10/16.. Loss: 0.7236.. Test accuracy: 0.6484.. 0.0193 s/batch
# Epoch: 10/16.. Loss: 0.7090.. Test accuracy: 0.6473.. 0.0198 s/batch
# Epoch: 10/16.. Loss: 0.6265.. Test accuracy: 0.6490.. 0.0199 s/batch
# Epoch: 10/16.. Loss: 0.6987.. Test accuracy: 0.6365.. 0.0206 s/batch
# Epoch: 10/16.. Loss: 0.6773.. Test accuracy: 0.6379.. 0.0213 s/batch
# Epoch: 11/16.. Loss: 0.6616.. Test accuracy: 0.6402.. 0.0350 s/batch
# Epoch: 11/16.. Loss: 0.6645.. Test accuracy: 0.6398.. 0.0197 s/batch
# Epoch: 11/16.. Loss: 0.6522.. Test accuracy: 0.6398.. 0.0197 s/batch
# Epoch: 11/16.. Loss: 0.6548.. Test accuracy: 0.6338.. 0.0205 s/batch
# Epoch: 11/16.. Loss: 0.6327.. Test accuracy: 0.6473.. 0.0204 s/batch
# Epoch: 11/16.. Loss: 0.6823.. Test accuracy: 0.6473.. 0.0194 s/batch
# Epoch: 11/16.. Loss: 0.6204.. Test accuracy: 0.6383.. 0.0201 s/batch
# Epoch: 11/16.. Loss: 0.6600.. Test accuracy: 0.6523.. 0.0198 s/batch
# Epoch: 11/16.. Loss: 0.6581.. Test accuracy: 0.6447.. 0.0198 s/batch
# Epoch: 11/16.. Loss: 0.6914.. Test accuracy: 0.6422.. 0.0197 s/batch
# Epoch: 11/16.. Loss: 0.6393.. Test accuracy: 0.6443.. 0.0200 s/batch
# Epoch: 11/16.. Loss: 0.6717.. Test accuracy: 0.6410.. 0.0206 s/batch
# Epoch: 11/16.. Loss: 0.6542.. Test accuracy: 0.6469.. 0.0206 s/batch
# Epoch: 11/16.. Loss: 0.6477.. Test accuracy: 0.6492.. 0.0204 s/batch
# Epoch: 11/16.. Loss: 0.6518.. Test accuracy: 0.6396.. 0.0196 s/batch
# Epoch: 11/16.. Loss: 0.6745.. Test accuracy: 0.6459.. 0.0195 s/batch
# Epoch: 11/16.. Loss: 0.6771.. Test accuracy: 0.6400.. 0.0195 s/batch
# Epoch: 11/16.. Loss: 0.7285.. Test accuracy: 0.6480.. 0.0206 s/batch
# Epoch: 11/16.. Loss: 0.7056.. Test accuracy: 0.6463.. 0.0210 s/batch
# Epoch: 11/16.. Loss: 0.6415.. Test accuracy: 0.6432.. 0.0204 s/batch
# Epoch: 11/16.. Loss: 0.6763.. Test accuracy: 0.6455.. 0.0200 s/batch
# Epoch: 11/16.. Loss: 0.6202.. Test accuracy: 0.6492.. 0.0192 s/batch
# Epoch: 11/16.. Loss: 0.6098.. Test accuracy: 0.6379.. 0.0198 s/batch
# Epoch: 11/16.. Loss: 0.6570.. Test accuracy: 0.6412.. 0.0201 s/batch
# Epoch: 11/16.. Loss: 0.6663.. Test accuracy: 0.6494.. 0.0203 s/batch
# Epoch: 11/16.. Loss: 0.6544.. Test accuracy: 0.6494.. 0.0199 s/batch
# Epoch: 11/16.. Loss: 0.6343.. Test accuracy: 0.6434.. 0.0196 s/batch
# Epoch: 11/16.. Loss: 0.6433.. Test accuracy: 0.6521.. 0.0197 s/batch
# Epoch: 11/16.. Loss: 0.6634.. Test accuracy: 0.6424.. 0.0197 s/batch
# Epoch: 11/16.. Loss: 0.6351.. Test accuracy: 0.6441.. 0.0200 s/batch
# Epoch: 11/16.. Loss: 0.7100.. Test accuracy: 0.6346.. 0.0207 s/batch
# Epoch: 11/16.. Loss: 0.6562.. Test accuracy: 0.6432.. 0.0202 s/batch
# Epoch: 11/16.. Loss: 0.6103.. Test accuracy: 0.6539.. 0.0195 s/batch
# Epoch: 11/16.. Loss: 0.6148.. Test accuracy: 0.6453.. 0.0202 s/batch
# Epoch: 11/16.. Loss: 0.6563.. Test accuracy: 0.6377.. 0.0197 s/batch
# Epoch: 11/16.. Loss: 0.6902.. Test accuracy: 0.6385.. 0.0193 s/batch
# Epoch: 11/16.. Loss: 0.6469.. Test accuracy: 0.6387.. 0.0198 s/batch
# Epoch: 11/16.. Loss: 0.6391.. Test accuracy: 0.6391.. 0.0198 s/batch
# Epoch: 12/16.. Loss: 0.7017.. Test accuracy: 0.6369.. 0.0281 s/batch
# Epoch: 12/16.. Loss: 0.6411.. Test accuracy: 0.6395.. 0.0200 s/batch
# Epoch: 12/16.. Loss: 0.6446.. Test accuracy: 0.6459.. 0.0196 s/batch
# Epoch: 12/16.. Loss: 0.6939.. Test accuracy: 0.6457.. 0.0199 s/batch
# Epoch: 12/16.. Loss: 0.6476.. Test accuracy: 0.6516.. 0.0204 s/batch
# Epoch: 12/16.. Loss: 0.6101.. Test accuracy: 0.6352.. 0.0210 s/batch
# Epoch: 12/16.. Loss: 0.6628.. Test accuracy: 0.6375.. 0.0196 s/batch
# Epoch: 12/16.. Loss: 0.6388.. Test accuracy: 0.6381.. 0.0192 s/batch
# Epoch: 12/16.. Loss: 0.6907.. Test accuracy: 0.6373.. 0.0194 s/batch
# Epoch: 12/16.. Loss: 0.6468.. Test accuracy: 0.6451.. 0.0206 s/batch
# Epoch: 12/16.. Loss: 0.7033.. Test accuracy: 0.6422.. 0.0206 s/batch
# Epoch: 12/16.. Loss: 0.6438.. Test accuracy: 0.6389.. 0.0199 s/batch
# Epoch: 12/16.. Loss: 0.6323.. Test accuracy: 0.6395.. 0.0194 s/batch
# Epoch: 12/16.. Loss: 0.6482.. Test accuracy: 0.6400.. 0.0193 s/batch
# Epoch: 12/16.. Loss: 0.6763.. Test accuracy: 0.6412.. 0.0198 s/batch
# Epoch: 12/16.. Loss: 0.6445.. Test accuracy: 0.6438.. 0.0211 s/batch
# Epoch: 12/16.. Loss: 0.6847.. Test accuracy: 0.6486.. 0.0200 s/batch
# Epoch: 12/16.. Loss: 0.6287.. Test accuracy: 0.6408.. 0.0195 s/batch
# Epoch: 12/16.. Loss: 0.6581.. Test accuracy: 0.6402.. 0.0199 s/batch
# Epoch: 12/16.. Loss: 0.6559.. Test accuracy: 0.6424.. 0.0193 s/batch
# Epoch: 12/16.. Loss: 0.6841.. Test accuracy: 0.6420.. 0.0206 s/batch
# Epoch: 12/16.. Loss: 0.6485.. Test accuracy: 0.6352.. 0.0197 s/batch
# Epoch: 12/16.. Loss: 0.6103.. Test accuracy: 0.6434.. 0.0202 s/batch
# Epoch: 12/16.. Loss: 0.6628.. Test accuracy: 0.6420.. 0.0198 s/batch
# Epoch: 12/16.. Loss: 0.6121.. Test accuracy: 0.6428.. 0.0194 s/batch
# Epoch: 12/16.. Loss: 0.6584.. Test accuracy: 0.6391.. 0.0195 s/batch
# Epoch: 12/16.. Loss: 0.6356.. Test accuracy: 0.6459.. 0.0197 s/batch
# Epoch: 12/16.. Loss: 0.7014.. Test accuracy: 0.6445.. 0.0202 s/batch
# Epoch: 12/16.. Loss: 0.6366.. Test accuracy: 0.6391.. 0.0208 s/batch
# Epoch: 12/16.. Loss: 0.6299.. Test accuracy: 0.6436.. 0.0198 s/batch
# Epoch: 12/16.. Loss: 0.6598.. Test accuracy: 0.6504.. 0.0206 s/batch
# Epoch: 12/16.. Loss: 0.6585.. Test accuracy: 0.6465.. 0.0195 s/batch
# Epoch: 12/16.. Loss: 0.6312.. Test accuracy: 0.6467.. 0.0203 s/batch
# Epoch: 12/16.. Loss: 0.6578.. Test accuracy: 0.6426.. 0.0207 s/batch
# Epoch: 12/16.. Loss: 0.7191.. Test accuracy: 0.6424.. 0.0204 s/batch
# Epoch: 12/16.. Loss: 0.6668.. Test accuracy: 0.6455.. 0.0202 s/batch
# Epoch: 12/16.. Loss: 0.6360.. Test accuracy: 0.6445.. 0.0195 s/batch
# Epoch: 12/16.. Loss: 0.6570.. Test accuracy: 0.6479.. 0.0197 s/batch
# Epoch: 13/16.. Loss: 0.6643.. Test accuracy: 0.6420.. 0.0151 s/batch
# Epoch: 13/16.. Loss: 0.6176.. Test accuracy: 0.6441.. 0.0206 s/batch
# Epoch: 13/16.. Loss: 0.6821.. Test accuracy: 0.6479.. 0.0203 s/batch
# Epoch: 13/16.. Loss: 0.6488.. Test accuracy: 0.6512.. 0.0196 s/batch
# Epoch: 13/16.. Loss: 0.6200.. Test accuracy: 0.6463.. 0.0204 s/batch
# Epoch: 13/16.. Loss: 0.7068.. Test accuracy: 0.6488.. 0.0210 s/batch
# Epoch: 13/16.. Loss: 0.6610.. Test accuracy: 0.6449.. 0.0194 s/batch
# Epoch: 13/16.. Loss: 0.6175.. Test accuracy: 0.6434.. 0.0210 s/batch
# Epoch: 13/16.. Loss: 0.6223.. Test accuracy: 0.6451.. 0.0198 s/batch
# Epoch: 13/16.. Loss: 0.6394.. Test accuracy: 0.6447.. 0.0190 s/batch
# Epoch: 13/16.. Loss: 0.6877.. Test accuracy: 0.6432.. 0.0207 s/batch
# Epoch: 13/16.. Loss: 0.6419.. Test accuracy: 0.6459.. 0.0197 s/batch
# Epoch: 13/16.. Loss: 0.6532.. Test accuracy: 0.6389.. 0.0200 s/batch
# Epoch: 13/16.. Loss: 0.6515.. Test accuracy: 0.6426.. 0.0201 s/batch
# Epoch: 13/16.. Loss: 0.6604.. Test accuracy: 0.6469.. 0.0201 s/batch
# Epoch: 13/16.. Loss: 0.6529.. Test accuracy: 0.6551.. 0.0195 s/batch
# Epoch: 13/16.. Loss: 0.6457.. Test accuracy: 0.6502.. 0.0191 s/batch
# Epoch: 13/16.. Loss: 0.6511.. Test accuracy: 0.6424.. 0.0196 s/batch
# Epoch: 13/16.. Loss: 0.6720.. Test accuracy: 0.6451.. 0.0199 s/batch
# Epoch: 13/16.. Loss: 0.6317.. Test accuracy: 0.6492.. 0.0202 s/batch
# Epoch: 13/16.. Loss: 0.6512.. Test accuracy: 0.6432.. 0.0194 s/batch
# Epoch: 13/16.. Loss: 0.6782.. Test accuracy: 0.6455.. 0.0190 s/batch
# Epoch: 13/16.. Loss: 0.6805.. Test accuracy: 0.6393.. 0.0201 s/batch
# Epoch: 13/16.. Loss: 0.6396.. Test accuracy: 0.6346.. 0.0198 s/batch
# Epoch: 13/16.. Loss: 0.6947.. Test accuracy: 0.6453.. 0.0207 s/batch
# Epoch: 13/16.. Loss: 0.6967.. Test accuracy: 0.6404.. 0.0211 s/batch
# Epoch: 13/16.. Loss: 0.6871.. Test accuracy: 0.6385.. 0.0204 s/batch
# Epoch: 13/16.. Loss: 0.6342.. Test accuracy: 0.6350.. 0.0194 s/batch
# Epoch: 13/16.. Loss: 0.6327.. Test accuracy: 0.6340.. 0.0195 s/batch
# Epoch: 13/16.. Loss: 0.6702.. Test accuracy: 0.6420.. 0.0196 s/batch
# Epoch: 13/16.. Loss: 0.6873.. Test accuracy: 0.6471.. 0.0207 s/batch
# Epoch: 13/16.. Loss: 0.6898.. Test accuracy: 0.6408.. 0.0205 s/batch
# Epoch: 13/16.. Loss: 0.6426.. Test accuracy: 0.6396.. 0.0194 s/batch
# Epoch: 13/16.. Loss: 0.6928.. Test accuracy: 0.6400.. 0.0198 s/batch
# Epoch: 13/16.. Loss: 0.6314.. Test accuracy: 0.6379.. 0.0195 s/batch
# Epoch: 13/16.. Loss: 0.6394.. Test accuracy: 0.6469.. 0.0196 s/batch
# Epoch: 13/16.. Loss: 0.5879.. Test accuracy: 0.6484.. 0.0202 s/batch
# Epoch: 13/16.. Loss: 0.6418.. Test accuracy: 0.6559.. 0.0203 s/batch
# Epoch: 14/16.. Loss: 0.6738.. Test accuracy: 0.6486.. 0.0157 s/batch
# Epoch: 14/16.. Loss: 0.6667.. Test accuracy: 0.6461.. 0.0198 s/batch
# Epoch: 14/16.. Loss: 0.6469.. Test accuracy: 0.6490.. 0.0194 s/batch
# Epoch: 14/16.. Loss: 0.7023.. Test accuracy: 0.6500.. 0.0191 s/batch
# Epoch: 14/16.. Loss: 0.6675.. Test accuracy: 0.6406.. 0.0192 s/batch
# Epoch: 14/16.. Loss: 0.6223.. Test accuracy: 0.6418.. 0.0199 s/batch
# Epoch: 14/16.. Loss: 0.6373.. Test accuracy: 0.6500.. 0.0198 s/batch
# Epoch: 14/16.. Loss: 0.6564.. Test accuracy: 0.6461.. 0.0195 s/batch
# Epoch: 14/16.. Loss: 0.6898.. Test accuracy: 0.6396.. 0.0204 s/batch
# Epoch: 14/16.. Loss: 0.6613.. Test accuracy: 0.6469.. 0.0205 s/batch
# Epoch: 14/16.. Loss: 0.6376.. Test accuracy: 0.6459.. 0.0198 s/batch
# Epoch: 14/16.. Loss: 0.6286.. Test accuracy: 0.6467.. 0.0198 s/batch
# Epoch: 14/16.. Loss: 0.6086.. Test accuracy: 0.6416.. 0.0197 s/batch
# Epoch: 14/16.. Loss: 0.6344.. Test accuracy: 0.6455.. 0.0205 s/batch
# Epoch: 14/16.. Loss: 0.6539.. Test accuracy: 0.6488.. 0.0202 s/batch
# Epoch: 14/16.. Loss: 0.6474.. Test accuracy: 0.6484.. 0.0197 s/batch
# Epoch: 14/16.. Loss: 0.6312.. Test accuracy: 0.6496.. 0.0216 s/batch
# Epoch: 14/16.. Loss: 0.6421.. Test accuracy: 0.6504.. 0.0208 s/batch
# Epoch: 14/16.. Loss: 0.6791.. Test accuracy: 0.6461.. 0.0201 s/batch
# Epoch: 14/16.. Loss: 0.6032.. Test accuracy: 0.6412.. 0.0202 s/batch
# Epoch: 14/16.. Loss: 0.6232.. Test accuracy: 0.6441.. 0.0212 s/batch
# Epoch: 14/16.. Loss: 0.6612.. Test accuracy: 0.6400.. 0.0205 s/batch
# Epoch: 14/16.. Loss: 0.6992.. Test accuracy: 0.6451.. 0.0203 s/batch
# Epoch: 14/16.. Loss: 0.6186.. Test accuracy: 0.6338.. 0.0212 s/batch
# Epoch: 14/16.. Loss: 0.6421.. Test accuracy: 0.6379.. 0.0206 s/batch
# Epoch: 14/16.. Loss: 0.6431.. Test accuracy: 0.6482.. 0.0202 s/batch
# Epoch: 14/16.. Loss: 0.6477.. Test accuracy: 0.6463.. 0.0205 s/batch
# Epoch: 14/16.. Loss: 0.6050.. Test accuracy: 0.6430.. 0.0212 s/batch
# Epoch: 14/16.. Loss: 0.6684.. Test accuracy: 0.6432.. 0.0197 s/batch
# Epoch: 14/16.. Loss: 0.6655.. Test accuracy: 0.6410.. 0.0207 s/batch
# Epoch: 14/16.. Loss: 0.7002.. Test accuracy: 0.6402.. 0.0200 s/batch
# Epoch: 14/16.. Loss: 0.6592.. Test accuracy: 0.6340.. 0.0209 s/batch
# Epoch: 14/16.. Loss: 0.6853.. Test accuracy: 0.6420.. 0.0190 s/batch
# Epoch: 14/16.. Loss: 0.6510.. Test accuracy: 0.6434.. 0.0194 s/batch
# Epoch: 14/16.. Loss: 0.6720.. Test accuracy: 0.6479.. 0.0192 s/batch
# Epoch: 14/16.. Loss: 0.6752.. Test accuracy: 0.6434.. 0.0202 s/batch
# Epoch: 14/16.. Loss: 0.7076.. Test accuracy: 0.6480.. 0.0204 s/batch
# Epoch: 14/16.. Loss: 0.6339.. Test accuracy: 0.6467.. 0.0203 s/batch
# Epoch: 14/16.. Loss: 0.6639.. Test accuracy: 0.6518.. 0.0209 s/batch
# Epoch: 15/16.. Loss: 0.6631.. Test accuracy: 0.6492.. 0.0321 s/batch
# Epoch: 15/16.. Loss: 0.6435.. Test accuracy: 0.6496.. 0.0249 s/batch
# Epoch: 15/16.. Loss: 0.6972.. Test accuracy: 0.6537.. 0.0203 s/batch
# Epoch: 15/16.. Loss: 0.6526.. Test accuracy: 0.6516.. 0.0241 s/batch
# Epoch: 15/16.. Loss: 0.7011.. Test accuracy: 0.6430.. 0.0204 s/batch
# Epoch: 15/16.. Loss: 0.6503.. Test accuracy: 0.6471.. 0.0219 s/batch
# Epoch: 15/16.. Loss: 0.6137.. Test accuracy: 0.6400.. 0.0205 s/batch
# Epoch: 15/16.. Loss: 0.6299.. Test accuracy: 0.6439.. 0.0212 s/batch
# Epoch: 15/16.. Loss: 0.6462.. Test accuracy: 0.6436.. 0.0208 s/batch
# Epoch: 15/16.. Loss: 0.6466.. Test accuracy: 0.6484.. 0.0207 s/batch
# Epoch: 15/16.. Loss: 0.6603.. Test accuracy: 0.6393.. 0.0210 s/batch
# Epoch: 15/16.. Loss: 0.6574.. Test accuracy: 0.6402.. 0.0206 s/batch
# Epoch: 15/16.. Loss: 0.6570.. Test accuracy: 0.6402.. 0.0201 s/batch
# Epoch: 15/16.. Loss: 0.6039.. Test accuracy: 0.6406.. 0.0207 s/batch
# Epoch: 15/16.. Loss: 0.6600.. Test accuracy: 0.6424.. 0.0202 s/batch
# Epoch: 15/16.. Loss: 0.6897.. Test accuracy: 0.6496.. 0.0209 s/batch
# Epoch: 15/16.. Loss: 0.6644.. Test accuracy: 0.6381.. 0.0199 s/batch
# Epoch: 15/16.. Loss: 0.6684.. Test accuracy: 0.6406.. 0.0204 s/batch
# Epoch: 15/16.. Loss: 0.6379.. Test accuracy: 0.6494.. 0.0203 s/batch
# Epoch: 15/16.. Loss: 0.5877.. Test accuracy: 0.6420.. 0.0205 s/batch
# Epoch: 15/16.. Loss: 0.6260.. Test accuracy: 0.6406.. 0.0211 s/batch
# Epoch: 15/16.. Loss: 0.6800.. Test accuracy: 0.6473.. 0.0207 s/batch
# Epoch: 15/16.. Loss: 0.6677.. Test accuracy: 0.6404.. 0.0209 s/batch
# Epoch: 15/16.. Loss: 0.7016.. Test accuracy: 0.6396.. 0.0202 s/batch
# Epoch: 15/16.. Loss: 0.6594.. Test accuracy: 0.6453.. 0.0198 s/batch
# Epoch: 15/16.. Loss: 0.5943.. Test accuracy: 0.6408.. 0.0203 s/batch
# Epoch: 15/16.. Loss: 0.6347.. Test accuracy: 0.6443.. 0.0199 s/batch
# Epoch: 15/16.. Loss: 0.7106.. Test accuracy: 0.6367.. 0.0221 s/batch
# Epoch: 15/16.. Loss: 0.6795.. Test accuracy: 0.6457.. 0.0209 s/batch
# Epoch: 15/16.. Loss: 0.6211.. Test accuracy: 0.6473.. 0.0214 s/batch
# Epoch: 15/16.. Loss: 0.6242.. Test accuracy: 0.6461.. 0.0202 s/batch
# Epoch: 15/16.. Loss: 0.6403.. Test accuracy: 0.6482.. 0.0208 s/batch
# Epoch: 15/16.. Loss: 0.6695.. Test accuracy: 0.6434.. 0.0213 s/batch
# Epoch: 15/16.. Loss: 0.6482.. Test accuracy: 0.6436.. 0.0200 s/batch
# Epoch: 15/16.. Loss: 0.7006.. Test accuracy: 0.6504.. 0.0209 s/batch
# Epoch: 15/16.. Loss: 0.6211.. Test accuracy: 0.6475.. 0.0209 s/batch
# Epoch: 15/16.. Loss: 0.6552.. Test accuracy: 0.6434.. 0.0205 s/batch
# Epoch: 15/16.. Loss: 0.6446.. Test accuracy: 0.6398.. 0.0214 s/batch
# Epoch: 16/16.. Loss: 0.6386.. Test accuracy: 0.6381.. 0.0257 s/batch
# Epoch: 16/16.. Loss: 0.6924.. Test accuracy: 0.6521.. 0.0206 s/batch
# Epoch: 16/16.. Loss: 0.6379.. Test accuracy: 0.6461.. 0.0201 s/batch
# Epoch: 16/16.. Loss: 0.6861.. Test accuracy: 0.6518.. 0.0203 s/batch
# Epoch: 16/16.. Loss: 0.6414.. Test accuracy: 0.6418.. 0.0203 s/batch
# Epoch: 16/16.. Loss: 0.6963.. Test accuracy: 0.6459.. 0.0214 s/batch
# Epoch: 16/16.. Loss: 0.6375.. Test accuracy: 0.6420.. 0.0220 s/batch
# Epoch: 16/16.. Loss: 0.6670.. Test accuracy: 0.6420.. 0.0218 s/batch
# Epoch: 16/16.. Loss: 0.6382.. Test accuracy: 0.6410.. 0.0205 s/batch
# Epoch: 16/16.. Loss: 0.6832.. Test accuracy: 0.6373.. 0.0206 s/batch
# Epoch: 16/16.. Loss: 0.6330.. Test accuracy: 0.6428.. 0.0215 s/batch
# Epoch: 16/16.. Loss: 0.6440.. Test accuracy: 0.6389.. 0.0209 s/batch
# Epoch: 16/16.. Loss: 0.6545.. Test accuracy: 0.6451.. 0.0221 s/batch
# Epoch: 16/16.. Loss: 0.6192.. Test accuracy: 0.6439.. 0.0214 s/batch
# Epoch: 16/16.. Loss: 0.6236.. Test accuracy: 0.6438.. 0.0213 s/batch
# Epoch: 16/16.. Loss: 0.5899.. Test accuracy: 0.6461.. 0.0201 s/batch
# Epoch: 16/16.. Loss: 0.6284.. Test accuracy: 0.6463.. 0.0204 s/batch
# Epoch: 16/16.. Loss: 0.6686.. Test accuracy: 0.6408.. 0.0203 s/batch
# Epoch: 16/16.. Loss: 0.6744.. Test accuracy: 0.6488.. 0.0206 s/batch
# Epoch: 16/16.. Loss: 0.6795.. Test accuracy: 0.6406.. 0.0214 s/batch
# Epoch: 16/16.. Loss: 0.6259.. Test accuracy: 0.6363.. 0.0211 s/batch
# Epoch: 16/16.. Loss: 0.7005.. Test accuracy: 0.6408.. 0.0212 s/batch
# Epoch: 16/16.. Loss: 0.6497.. Test accuracy: 0.6455.. 0.0200 s/batch
# Epoch: 16/16.. Loss: 0.6536.. Test accuracy: 0.6434.. 0.0201 s/batch
# Epoch: 16/16.. Loss: 0.6545.. Test accuracy: 0.6434.. 0.0214 s/batch
# Epoch: 16/16.. Loss: 0.6528.. Test accuracy: 0.6461.. 0.0204 s/batch
# Epoch: 16/16.. Loss: 0.6491.. Test accuracy: 0.6422.. 0.0216 s/batch
# Epoch: 16/16.. Loss: 0.6603.. Test accuracy: 0.6482.. 0.0205 s/batch
# Epoch: 16/16.. Loss: 0.6736.. Test accuracy: 0.6439.. 0.0208 s/batch
# Epoch: 16/16.. Loss: 0.6302.. Test accuracy: 0.6438.. 0.0202 s/batch
# Epoch: 16/16.. Loss: 0.6785.. Test accuracy: 0.6473.. 0.0198 s/batch
# Epoch: 16/16.. Loss: 0.6110.. Test accuracy: 0.6492.. 0.0192 s/batch
# Epoch: 16/16.. Loss: 0.6253.. Test accuracy: 0.6510.. 0.0198 s/batch
# Epoch: 16/16.. Loss: 0.6841.. Test accuracy: 0.6416.. 0.0209 s/batch
# Epoch: 16/16.. Loss: 0.6239.. Test accuracy: 0.6482.. 0.0209 s/batch
# Epoch: 16/16.. Loss: 0.6514.. Test accuracy: 0.6500.. 0.0209 s/batch
# Epoch: 16/16.. Loss: 0.6584.. Test accuracy: 0.6488.. 0.0204 s/batch
# Epoch: 16/16.. Loss: 0.6137.. Test accuracy: 0.6459.. 0.0199 s/batch

# %% [markdown]
# Save best trained model.

# %%
## You should be familiar with how to save a pytorch model (Make sure to save the model in your Drive)
torch.save(net.state_dict(), 'drive/MyDrive/Colab Notebooks/Cifar10_Classifier_pytorch_CUDA.ckpt')

# %%
checkpoint = torch.load("drive/MyDrive/Colab Notebooks/Cifar10_Classifier_pytorch_CUDA.ckpt")
net.load_state_dict(checkpoint)
# Out:
# <All keys matched successfully>
